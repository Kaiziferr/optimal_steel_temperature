# %%
import warnings

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import (
    train_test_split
)

from sklearn.metrics import mean_absolute_error

from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# # **Config**
# ---

# %%
random_seed = 12354
sns.set(style="darkgrid")
sns.set(font_scale=1)
pd.set_option('display.float_format', '{:,.5f}'.format)
title_data = 'Temperature prediction'
paleta = sns.color_palette("tab10").as_hex()
warnings.filterwarnings("ignore")

# %%
wra_regressor = LazyRegressor(
    verbose=0,
    ignore_warnings=True, 
    custom_metric=mean_absolute_error, 
    predictions=True, 
    regressors ='all' )

# %% [markdown]
# # **Data First Strategy**
# ---

# %%
data_first = pd.read_csv('../data/first_strategy.csv')

# %% [markdown]
# **Split**

# %%
X = data_first[[
    'active_power_sum', 'reactive_power_sum', 'minutes_process_sum',
    'gas_purgue'
]]

y = data_first['temperature_sum']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    train_size=0.85,
    shuffle=True,
    random_state=random_seed
)

# %%
regressor_model_first_strategy , predictions  = wra_regressor.fit(
    X_train,
    X_test,
    y_train,
    y_test
)
# Out:
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████| 42/42 [00:05<00:00,  7.56it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000127 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 2731, number of used features: 4
# [LightGBM] [Info] Start training from score 6492.621384

# %%
GradientBoostingRegressor
AdaBoostRegressor
HistGradientBoostingRegressor
DummyRegressor
RandomForestRegressor
XGBRegressor

# %%
regressor_model_first_strategy.sort_values('mean_absolute_error')
# Out:
#                                                               Adjusted R-Squared  \
# Model
# GradientBoostingRegressor                                                0.01136
# OrthogonalMatchingPursuit                                                0.03432
# GammaRegressor                                                           0.04228
# AdaBoostRegressor                                                       -0.00980
# HistGradientBoostingRegressor                                           -0.01366
# LGBMRegressor                                                           -0.01459
# SVR                                                                     -0.00782
# NuSVR                                                                   -0.00745
# QuantileRegressor                                                       -0.01237
# DummyRegressor                                                          -0.01833
# RandomForestRegressor                                                   -0.07431
# XGBRegressor                                                            -0.11609
# ExtraTreesRegressor                                                     -0.10450
# BaggingRegressor                                                        -0.14521
# ElasticNet                                                              -2.35962
# PassiveAggressiveRegressor                                              -3.16339
# ElasticNetCV                                                            -2.43254
# TweedieRegressor                                                        -2.42907
# KNeighborsRegressor                                                     -0.17249
# SGDRegressor                                                            -6.85321
# HuberRegressor                                                         -10.53486
# BayesianRidge                                                          -19.64956
# Lasso                                                                  -24.84290
# LassoLars                                                              -24.88080
# LassoCV                                                                -24.89152
# Ridge                                                                  -25.90380
# RidgeCV                                                                -25.90380
# TransformedTargetRegressor                                             -26.97378
# LinearRegression                                                       -26.97378
# OrthogonalMatchingPursuitCV                                            -26.97378
# Lars                                                                   -26.97378
# LarsCV                                                                 -26.97378
# LassoLarsIC                                                            -26.97378
# LassoLarsCV                                                            -26.97378
# ExtraTreeRegressor                                                      -1.02435
# DecisionTreeRegressor                                                   -1.18069
# LinearSVR                                                               -1.70904
# MLPRegressor                                                           -22.49006
# KernelRidge                                                            -28.18505
# RANSACRegressor                                                     -5,048.56886
# GaussianProcessRegressor                                          -462,460.50149
# PoissonRegressor              -4,076,762,559,013,475,140,585,770,618,757,323,...
#
#                                                                        R-Squared  \
# Model
# GradientBoostingRegressor                                                0.01957
# OrthogonalMatchingPursuit                                                0.04233
# GammaRegressor                                                           0.05023
# AdaBoostRegressor                                                       -0.00142
# HistGradientBoostingRegressor                                           -0.00525
# LGBMRegressor                                                           -0.00617
# SVR                                                                      0.00054
# NuSVR                                                                    0.00091
# QuantileRegressor                                                       -0.00397
# DummyRegressor                                                          -0.00988
# RandomForestRegressor                                                   -0.06539
# XGBRegressor                                                            -0.10682
# ExtraTreesRegressor                                                     -0.09533
# BaggingRegressor                                                        -0.13570
# ElasticNet                                                              -2.33174
# PassiveAggressiveRegressor                                              -3.12884
# ElasticNetCV                                                            -2.40405
# TweedieRegressor                                                        -2.40061
# KNeighborsRegressor                                                     -0.16276
# SGDRegressor                                                            -6.78804
# HuberRegressor                                                         -10.43914
# BayesianRidge                                                          -19.47819
# Lasso                                                                  -24.62844
# LassoLars                                                              -24.66602
# LassoCV                                                                -24.67666
# Ridge                                                                  -25.68053
# RidgeCV                                                                -25.68053
# TransformedTargetRegressor                                             -26.74164
# LinearRegression                                                       -26.74164
# OrthogonalMatchingPursuitCV                                            -26.74164
# Lars                                                                   -26.74164
# LarsCV                                                                 -26.74164
# LassoLarsIC                                                            -26.74164
# LassoLarsCV                                                            -26.74164
# ExtraTreeRegressor                                                      -1.00755
# DecisionTreeRegressor                                                   -1.16260
# LinearSVR                                                               -1.68656
# MLPRegressor                                                           -22.29513
# KernelRidge                                                            -27.94285
# RANSACRegressor                                                     -5,006.66372
# GaussianProcessRegressor                                          -458,622.64671
# PoissonRegressor              -4,042,930,504,581,828,318,679,602,175,112,250,...
#
#                                                                      RMSE  \
# Model
# GradientBoostingRegressor                                     3,444.53929
# OrthogonalMatchingPursuit                                     3,404.31949
# GammaRegressor                                                3,390.25055
# AdaBoostRegressor                                             3,481.21416
# HistGradientBoostingRegressor                                 3,487.86675
# LGBMRegressor                                                 3,489.46143
# SVR                                                           3,477.80063
# NuSVR                                                         3,477.16173
# QuantileRegressor                                             3,485.63828
# DummyRegressor                                                3,495.88260
# RandomForestRegressor                                         3,590.68488
# XGBRegressor                                                  3,659.83911
# ExtraTreesRegressor                                           3,640.79197
# BaggingRegressor                                              3,707.27540
# ElasticNet                                                    6,349.76968
# PassiveAggressiveRegressor                                    7,068.64766
# ElasticNetCV                                                  6,418.31193
# TweedieRegressor                                              6,415.06220
# KNeighborsRegressor                                           3,751.17825
# SGDRegressor                                                  9,708.15336
# HuberRegressor                                               11,765.73894
# BayesianRidge                                                15,742.30654
# Lasso                                                        17,610.98433
# LassoLars                                                    17,623.89366
# LassoCV                                                      17,627.54395
# Ridge                                                        17,968.82952
# RidgeCV                                                      17,968.82952
# TransformedTargetRegressor                                   18,322.66365
# LinearRegression                                             18,322.66365
# OrthogonalMatchingPursuitCV                                  18,322.66365
# Lars                                                         18,322.66365
# LarsCV                                                       18,322.66365
# LassoLarsIC                                                  18,322.66365
# LassoLarsCV                                                  18,322.66365
# ExtraTreeRegressor                                            4,928.96037
# DecisionTreeRegressor                                         5,115.76096
# LinearSVR                                                     5,701.91766
# MLPRegressor                                                 16,790.17003
# KernelRidge                                                  18,715.14565
# RANSACRegressor                                             246,172.84489
# GaussianProcessRegressor                                  2,355,867.10236
# PoissonRegressor              6,994,725,956,439,352,351,752,454,144.00000
#
#                                Time Taken  \
# Model
# GradientBoostingRegressor         0.37844
# OrthogonalMatchingPursuit         0.00868
# GammaRegressor                    0.01043
# AdaBoostRegressor                 0.05836
# HistGradientBoostingRegressor     0.15253
# LGBMRegressor                     0.06161
# SVR                               0.26304
# NuSVR                             0.17819
# QuantileRegressor                 0.18304
# DummyRegressor                    0.00608
# RandomForestRegressor             1.16106
# XGBRegressor                      0.15220
# ExtraTreesRegressor               0.35679
# BaggingRegressor                  0.12134
# ElasticNet                        0.00524
# PassiveAggressiveRegressor        0.01930
# ElasticNetCV                      0.04732
# TweedieRegressor                  0.00841
# KNeighborsRegressor               0.00937
# SGDRegressor                      0.01731
# HuberRegressor                    0.01429
# BayesianRidge                     0.00631
# Lasso                             0.01761
# LassoLars                         0.00883
# LassoCV                           0.08491
# Ridge                             0.02220
# RidgeCV                           0.03147
# TransformedTargetRegressor        0.00978
# LinearRegression                  0.00524
# OrthogonalMatchingPursuitCV       0.01250
# Lars                              0.00810
# LarsCV                            0.01343
# LassoLarsIC                       0.00855
# LassoLarsCV                       0.01427
# ExtraTreeRegressor                0.01022
# DecisionTreeRegressor             0.02336
# LinearSVR                         0.00797
# MLPRegressor                      0.69880
# KernelRidge                       0.42134
# RANSACRegressor                   0.05987
# GaussianProcessRegressor          0.83569
# PoissonRegressor                  0.01255
#
#                                                     mean_absolute_error
# Model
# GradientBoostingRegressor                                   2,664.34082
# OrthogonalMatchingPursuit                                   2,695.19192
# GammaRegressor                                              2,705.52161
# AdaBoostRegressor                                           2,715.79042
# HistGradientBoostingRegressor                               2,743.51814
# LGBMRegressor                                               2,763.08134
# SVR                                                         2,776.24835
# NuSVR                                                       2,776.52756
# QuantileRegressor                                           2,784.07039
# DummyRegressor                                              2,802.49959
# RandomForestRegressor                                       2,844.29414
# XGBRegressor                                                2,885.09596
# ExtraTreesRegressor                                         2,888.06509
# BaggingRegressor                                            2,908.42650
# ElasticNet                                                  2,924.20678
# PassiveAggressiveRegressor                                  2,939.83891
# ElasticNetCV                                                2,941.78841
# TweedieRegressor                                            2,942.10272
# KNeighborsRegressor                                         2,994.97308
# SGDRegressor                                                3,068.73480
# HuberRegressor                                              3,169.39910
# BayesianRidge                                               3,349.75236
# Lasso                                                       3,436.74476
# LassoLars                                                   3,437.34198
# LassoCV                                                     3,437.51819
# Ridge                                                       3,453.46034
# RidgeCV                                                     3,453.46034
# TransformedTargetRegressor                                  3,469.99818
# LinearRegression                                            3,469.99818
# OrthogonalMatchingPursuitCV                                 3,469.99818
# Lars                                                        3,469.99818
# LarsCV                                                      3,469.99818
# LassoLarsIC                                                 3,469.99818
# LassoLarsCV                                                 3,469.99818
# ExtraTreeRegressor                                          3,809.82816
# DecisionTreeRegressor                                       3,892.65631
# LinearSVR                                                   4,533.67582
# MLPRegressor                                                5,006.95840
# KernelRidge                                                 6,959.16401
# RANSACRegressor                                            14,405.66002
# GaussianProcessRegressor                                  254,577.49163
# PoissonRegressor              318,271,051,343,936,037,517,787,136.00000

# %% [markdown]
# # **Data Second Strategy**
# ---

# %%
data_second = pd.read_csv('../data/second_strategy.csv')

# %%
data_second
# Out:
#        key  temperature_sum  active_power_sum  reactive_power_sum  \
# 0        1      8,007.00000           4.87815             3.18324
# 1       10     12,678.00000           2.92362             2.49612
# 2      100      6,295.00000           4.43513             3.15134
# 3     1000      9,575.00000           1.40241             0.93353
# 4     1001     14,293.00000           4.24727             3.37764
# ...    ...              ...               ...                 ...
# 3209   995      9,542.00000           1.90945             1.48719
# 3210   996      7,986.00000           1.19491             0.89953
# 3211   997      4,762.00000           1.93813             1.56647
# 3212   998      9,482.00000           2.17320             1.51996
# 3213   999      6,375.00000           1.97664             1.45589
#
#       minutes_process_sum  gas_purgue         C1         C2        C3
# 0                18.30000    29.74999   20.66459  -39.52270 -28.69459
# 1                13.74900     6.52989   22.22047  -63.83044  16.63654
# 2                17.71700    12.64319   20.94804  -26.35074 -21.89425
# 3                 6.75100     9.80073 -251.22053    4.11963 158.15935
# 4                18.86600    19.67891 -253.90412  -18.30161 114.97372
# ...                   ...         ...        ...        ...       ...
# 3209              8.85000    12.30884   -3.19796  -97.93836 -16.53886
# 3210              8.23300     8.83820    7.08725 -105.39740 -32.67329
# 3211             10.11700     7.48937  -13.82826  -46.86487 -13.20168
# 3212              9.48300     4.22033 -254.64611 -104.83379   5.76944
# 3213             10.88300    14.07026   -8.08360   36.43761 131.87718
#
# [3214 rows x 9 columns]

# %%
X = data_second[[
    'active_power_sum', 'reactive_power_sum', 'minutes_process_sum',
    'gas_purgue', 'C1', 'C2', 'C3'
]]

y = data_second['temperature_sum']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    train_size=0.85,
    shuffle=True,
    random_state=random_seed
)

# %%
regressor_model_second_strategy , predictions  = wra_regressor.fit(
    X_train,
    X_test,
    y_train,
    y_test
)
# Out:
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████| 42/42 [00:06<00:00,  6.79it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1785
# [LightGBM] [Info] Number of data points in the train set: 2731, number of used features: 7
# [LightGBM] [Info] Start training from score 6492.621384

# %%
regressor_model_second_strategy.sort_values('mean_absolute_error')
# Out:
#                                                               Adjusted R-Squared  \
# Model
# OrthogonalMatchingPursuitCV                                              0.03759
# OrthogonalMatchingPursuit                                                0.02822
# RandomForestRegressor                                                   -0.00781
# KNeighborsRegressor                                                     -0.01389
# GradientBoostingRegressor                                               -0.03353
# GammaRegressor                                                           0.03662
# HistGradientBoostingRegressor                                            0.00319
# LGBMRegressor                                                           -0.01546
# ExtraTreesRegressor                                                     -0.00808
# SVR                                                                     -0.01528
# NuSVR                                                                   -0.01510
# QuantileRegressor                                                       -0.01876
# DummyRegressor                                                          -0.02476
# AdaBoostRegressor                                                       -0.11383
# BaggingRegressor                                                        -0.08850
# XGBRegressor                                                            -0.18019
# ElasticNet                                                              -2.69156
# ElasticNetCV                                                            -2.58265
# TweedieRegressor                                                        -2.57563
# PassiveAggressiveRegressor                                              -3.86591
# SGDRegressor                                                           -11.70982
# HuberRegressor                                                         -14.09683
# BayesianRidge                                                          -19.25499
# Lasso                                                                  -33.94217
# LassoLars                                                              -33.98568
# LassoCV                                                                -34.00097
# Ridge                                                                  -35.13847
# RidgeCV                                                                -35.13847
# TransformedTargetRegressor                                             -36.51529
# LinearRegression                                                       -36.51529
# Lars                                                                   -36.51529
# LarsCV                                                                 -36.51529
# LassoLarsIC                                                            -36.51529
# LassoLarsCV                                                            -36.51529
# ExtraTreeRegressor                                                      -1.06125
# DecisionTreeRegressor                                                   -1.07613
# LinearSVR                                                               -1.72033
# MLPRegressor                                                           -20.41458
# RANSACRegressor                                                       -171.17659
# KernelRidge                                                            -37.27523
# GaussianProcessRegressor                                               -74.24490
# PoissonRegressor              -9,406,005,854,851,068,861,773,065,254,160,264,...
#
#                                                                        R-Squared  \
# Model
# OrthogonalMatchingPursuitCV                                              0.05157
# OrthogonalMatchingPursuit                                                0.04233
# RandomForestRegressor                                                    0.00683
# KNeighborsRegressor                                                      0.00084
# GradientBoostingRegressor                                               -0.01852
# GammaRegressor                                                           0.05062
# HistGradientBoostingRegressor                                            0.01767
# LGBMRegressor                                                           -0.00072
# ExtraTreesRegressor                                                      0.00656
# SVR                                                                     -0.00054
# NuSVR                                                                   -0.00036
# QuantileRegressor                                                       -0.00397
# DummyRegressor                                                          -0.00988
# AdaBoostRegressor                                                       -0.09765
# BaggingRegressor                                                        -0.07269
# XGBRegressor                                                            -0.16305
# ElasticNet                                                              -2.63795
# ElasticNetCV                                                            -2.53062
# TweedieRegressor                                                        -2.52370
# PassiveAggressiveRegressor                                              -3.79524
# SGDRegressor                                                           -11.52524
# HuberRegressor                                                         -13.87758
# BayesianRidge                                                          -18.96083
# Lasso                                                                  -33.43471
# LassoLars                                                              -33.47758
# LassoCV                                                                -33.49266
# Ridge                                                                  -34.61364
# RidgeCV                                                                -34.61364
# TransformedTargetRegressor                                             -35.97046
# LinearRegression                                                       -35.97046
# Lars                                                                   -35.97046
# LarsCV                                                                 -35.97046
# LassoLarsIC                                                            -35.97046
# LassoLarsCV                                                            -35.97046
# ExtraTreeRegressor                                                      -1.03131
# DecisionTreeRegressor                                                   -1.04598
# LinearSVR                                                               -1.68082
# MLPRegressor                                                           -20.10358
# RANSACRegressor                                                       -168.67610
# KernelRidge                                                            -36.71937
# GaussianProcessRegressor                                               -73.15213
# PoissonRegressor              -9,269,404,110,071,074,372,049,931,351,938,498,...
#
#                                                                            RMSE  \
# Model
# OrthogonalMatchingPursuitCV                                         3,387.86135
# OrthogonalMatchingPursuit                                           3,404.31949
# RandomForestRegressor                                               3,466.85156
# KNeighborsRegressor                                                 3,477.29110
# GradientBoostingRegressor                                           3,510.81320
# GammaRegressor                                                      3,389.56180
# HistGradientBoostingRegressor                                       3,447.87981
# LGBMRegressor                                                       3,479.99158
# ExtraTreesRegressor                                                 3,467.30850
# SVR                                                                 3,479.67963
# NuSVR                                                               3,479.37385
# QuantileRegressor                                                   3,485.63828
# DummyRegressor                                                      3,495.88260
# AdaBoostRegressor                                                   3,644.63893
# BaggingRegressor                                                    3,602.95870
# XGBRegressor                                                        3,751.64318
# ElasticNet                                                          6,635.15256
# ElasticNetCV                                                        6,536.54175
# TweedieRegressor                                                    6,530.13497
# PassiveAggressiveRegressor                                          7,617.77136
# SGDRegressor                                                       12,311.63102
# HuberRegressor                                                     13,418.02951
# BayesianRidge                                                      15,542.17891
# Lasso                                                              20,413.65519
# LassoLars                                                          20,426.36006
# LassoCV                                                            20,430.82392
# Ridge                                                              20,760.16160
# RidgeCV                                                            20,760.16160
# TransformedTargetRegressor                                         21,151.93061
# LinearRegression                                                   21,151.93061
# Lars                                                               21,151.93061
# LarsCV                                                             21,151.93061
# LassoLarsIC                                                        21,151.93061
# LassoLarsCV                                                        21,151.93061
# ExtraTreeRegressor                                                  4,958.05212
# DecisionTreeRegressor                                               4,975.92111
# LinearSVR                                                           5,695.82616
# MLPRegressor                                                       15,980.87850
# RANSACRegressor                                                    45,314.05235
# KernelRidge                                                        21,365.09218
# GaussianProcessRegressor                                           29,956.03796
# PoissonRegressor              334,925,700,287,984,342,782,825,923,084,288.00000
#
#                                Time Taken  \
# Model
# OrthogonalMatchingPursuitCV       0.01029
# OrthogonalMatchingPursuit         0.00844
# RandomForestRegressor             1.74138
# KNeighborsRegressor               0.01152
# GradientBoostingRegressor         0.60625
# GammaRegressor                    0.00873
# HistGradientBoostingRegressor     0.15628
# LGBMRegressor                     0.05825
# ExtraTreesRegressor               0.46335
# SVR                               0.19475
# NuSVR                             0.15138
# QuantileRegressor                 0.18389
# DummyRegressor                    0.00741
# AdaBoostRegressor                 0.14469
# BaggingRegressor                  0.18138
# XGBRegressor                      0.18645
# ElasticNet                        0.00542
# ElasticNetCV                      0.04561
# TweedieRegressor                  0.00729
# PassiveAggressiveRegressor        0.01224
# SGDRegressor                      0.01062
# HuberRegressor                    0.01742
# BayesianRidge                     0.00684
# Lasso                             0.00925
# LassoLars                         0.00759
# LassoCV                           0.07504
# Ridge                             0.00764
# RidgeCV                           0.00676
# TransformedTargetRegressor        0.00709
# LinearRegression                  0.00734
# Lars                              0.01071
# LarsCV                            0.01766
# LassoLarsIC                       0.01065
# LassoLarsCV                       0.01328
# ExtraTreeRegressor                0.01058
# DecisionTreeRegressor             0.03185
# LinearSVR                         0.00966
# MLPRegressor                      0.75401
# RANSACRegressor                   0.06243
# KernelRidge                       0.34570
# GaussianProcessRegressor          0.53922
# PoissonRegressor                  0.01057
#
#                                                            mean_absolute_error
# Model
# OrthogonalMatchingPursuitCV                                        2,651.02085
# OrthogonalMatchingPursuit                                          2,695.19192
# RandomForestRegressor                                              2,696.51344
# KNeighborsRegressor                                                2,699.72588
# GradientBoostingRegressor                                          2,701.88038
# GammaRegressor                                                     2,706.20187
# HistGradientBoostingRegressor                                      2,709.33345
# LGBMRegressor                                                      2,715.69431
# ExtraTreesRegressor                                                2,729.30139
# SVR                                                                2,778.30082
# NuSVR                                                              2,778.43567
# QuantileRegressor                                                  2,784.07039
# DummyRegressor                                                     2,802.49959
# AdaBoostRegressor                                                  2,808.44104
# BaggingRegressor                                                   2,820.87184
# XGBRegressor                                                       2,903.63780
# ElasticNet                                                         2,938.53681
# ElasticNetCV                                                       2,948.22789
# TweedieRegressor                                                   2,948.41854
# PassiveAggressiveRegressor                                         2,965.69259
# SGDRegressor                                                       3,195.78940
# HuberRegressor                                                     3,235.43882
# BayesianRidge                                                      3,339.92143
# Lasso                                                              3,563.42078
# LassoLars                                                          3,564.01102
# LassoCV                                                            3,564.21766
# Ridge                                                              3,579.58714
# RidgeCV                                                            3,579.58714
# TransformedTargetRegressor                                         3,597.73865
# LinearRegression                                                   3,597.73865
# Lars                                                               3,597.73865
# LarsCV                                                             3,597.73865
# LassoLarsIC                                                        3,597.73865
# LassoLarsCV                                                        3,597.73865
# ExtraTreeRegressor                                                 3,783.08903
# DecisionTreeRegressor                                              3,801.78675
# LinearSVR                                                          4,532.57692
# MLPRegressor                                                       4,908.35478
# RANSACRegressor                                                    6,175.48951
# KernelRidge                                                        7,072.19667
# GaussianProcessRegressor                                          19,398.64841
# PoissonRegressor              15,239,647,045,017,873,342,229,844,590,592.00000

# %% [markdown]
# # **Data Third Strategy**
# ---

# %%
data_third = pd.read_csv('../data/third_strategy.csv')

# %%
data_third
# Out:
#        key  temperature_sum         C1         C2        C3        C4  \
# 0        1      8,007.00000   20.88850  -39.17555 -28.85761  29.09527
# 1       10     12,678.00000   22.18162  -63.91922  16.61842  59.46159
# 2      100      6,295.00000   21.03320  -26.25830 -21.93474  31.55612
# 3     1000      9,575.00000 -251.30467    3.99810 158.15087 -53.95510
# 4     1001     14,293.00000 -253.70081  -18.05334 114.83498 -55.43850
# ...    ...              ...        ...        ...       ...       ...
# 3209   995      9,542.00000   -3.27465  -97.94387 -16.63067  -5.72901
# 3210   996      7,986.00000    6.96749 -105.44653 -32.75088   9.37505
# 3211   997      4,762.00000  -13.91689  -46.96295 -13.19838 -29.78941
# 3212   998      9,482.00000 -254.73121 -104.84294   5.68684 -38.86811
# 3213   999      6,375.00000   -8.10456   36.32399 131.89901 -37.58493
#
#             C5
# 0    -22.80295
# 1    -69.01695
# 2    -36.21207
# 3     43.78298
# 4     14.96360
# ...        ...
# 3209  50.51911
# 3210  77.10562
# 3211 -63.18561
# 3212  15.45676
# 3213  12.04590
#
# [3214 rows x 7 columns]

# %%
X = data_third[[
    "C1", "C2", "C3", "C4", "C5"
]]

y = data_third['temperature_sum']

# %%
regressor_model_third_strategy , predictions  = wra_regressor.fit(
    X_train,
    X_test,
    y_train,
    y_test
)
# Out:
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████| 42/42 [00:06<00:00,  6.17it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000078 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1785
# [LightGBM] [Info] Number of data points in the train set: 2731, number of used features: 7
# [LightGBM] [Info] Start training from score 6492.621384

# %%
regressor_model_third_strategy.sort_values('mean_absolute_error')
# Out:
#                                                               Adjusted R-Squared  \
# Model
# OrthogonalMatchingPursuitCV                                              0.03759
# OrthogonalMatchingPursuit                                                0.02822
# RandomForestRegressor                                                   -0.00781
# KNeighborsRegressor                                                     -0.01389
# GradientBoostingRegressor                                               -0.03353
# GammaRegressor                                                           0.03662
# HistGradientBoostingRegressor                                            0.00319
# LGBMRegressor                                                           -0.01546
# ExtraTreesRegressor                                                     -0.00808
# SVR                                                                     -0.01528
# NuSVR                                                                   -0.01510
# QuantileRegressor                                                       -0.01876
# DummyRegressor                                                          -0.02476
# AdaBoostRegressor                                                       -0.11383
# BaggingRegressor                                                        -0.08850
# XGBRegressor                                                            -0.18019
# ElasticNet                                                              -2.69156
# ElasticNetCV                                                            -2.58265
# TweedieRegressor                                                        -2.57563
# PassiveAggressiveRegressor                                              -3.86591
# SGDRegressor                                                           -11.70982
# HuberRegressor                                                         -14.09683
# BayesianRidge                                                          -19.25499
# Lasso                                                                  -33.94217
# LassoLars                                                              -33.98568
# LassoCV                                                                -34.00097
# Ridge                                                                  -35.13847
# RidgeCV                                                                -35.13847
# TransformedTargetRegressor                                             -36.51529
# LinearRegression                                                       -36.51529
# Lars                                                                   -36.51529
# LarsCV                                                                 -36.51529
# LassoLarsIC                                                            -36.51529
# LassoLarsCV                                                            -36.51529
# ExtraTreeRegressor                                                      -1.06125
# DecisionTreeRegressor                                                   -1.07613
# LinearSVR                                                               -1.72033
# MLPRegressor                                                           -20.41458
# RANSACRegressor                                                       -171.17659
# KernelRidge                                                            -37.27523
# GaussianProcessRegressor                                               -74.24490
# PoissonRegressor              -9,406,005,854,851,068,861,773,065,254,160,264,...
#
#                                                                        R-Squared  \
# Model
# OrthogonalMatchingPursuitCV                                              0.05157
# OrthogonalMatchingPursuit                                                0.04233
# RandomForestRegressor                                                    0.00683
# KNeighborsRegressor                                                      0.00084
# GradientBoostingRegressor                                               -0.01852
# GammaRegressor                                                           0.05062
# HistGradientBoostingRegressor                                            0.01767
# LGBMRegressor                                                           -0.00072
# ExtraTreesRegressor                                                      0.00656
# SVR                                                                     -0.00054
# NuSVR                                                                   -0.00036
# QuantileRegressor                                                       -0.00397
# DummyRegressor                                                          -0.00988
# AdaBoostRegressor                                                       -0.09765
# BaggingRegressor                                                        -0.07269
# XGBRegressor                                                            -0.16305
# ElasticNet                                                              -2.63795
# ElasticNetCV                                                            -2.53062
# TweedieRegressor                                                        -2.52370
# PassiveAggressiveRegressor                                              -3.79524
# SGDRegressor                                                           -11.52524
# HuberRegressor                                                         -13.87758
# BayesianRidge                                                          -18.96083
# Lasso                                                                  -33.43471
# LassoLars                                                              -33.47758
# LassoCV                                                                -33.49266
# Ridge                                                                  -34.61364
# RidgeCV                                                                -34.61364
# TransformedTargetRegressor                                             -35.97046
# LinearRegression                                                       -35.97046
# Lars                                                                   -35.97046
# LarsCV                                                                 -35.97046
# LassoLarsIC                                                            -35.97046
# LassoLarsCV                                                            -35.97046
# ExtraTreeRegressor                                                      -1.03131
# DecisionTreeRegressor                                                   -1.04598
# LinearSVR                                                               -1.68082
# MLPRegressor                                                           -20.10358
# RANSACRegressor                                                       -168.67610
# KernelRidge                                                            -36.71937
# GaussianProcessRegressor                                               -73.15213
# PoissonRegressor              -9,269,404,110,071,074,372,049,931,351,938,498,...
#
#                                                                            RMSE  \
# Model
# OrthogonalMatchingPursuitCV                                         3,387.86135
# OrthogonalMatchingPursuit                                           3,404.31949
# RandomForestRegressor                                               3,466.85156
# KNeighborsRegressor                                                 3,477.29110
# GradientBoostingRegressor                                           3,510.81320
# GammaRegressor                                                      3,389.56180
# HistGradientBoostingRegressor                                       3,447.87981
# LGBMRegressor                                                       3,479.99158
# ExtraTreesRegressor                                                 3,467.30850
# SVR                                                                 3,479.67963
# NuSVR                                                               3,479.37385
# QuantileRegressor                                                   3,485.63828
# DummyRegressor                                                      3,495.88260
# AdaBoostRegressor                                                   3,644.63893
# BaggingRegressor                                                    3,602.95870
# XGBRegressor                                                        3,751.64318
# ElasticNet                                                          6,635.15256
# ElasticNetCV                                                        6,536.54175
# TweedieRegressor                                                    6,530.13497
# PassiveAggressiveRegressor                                          7,617.77136
# SGDRegressor                                                       12,311.63102
# HuberRegressor                                                     13,418.02951
# BayesianRidge                                                      15,542.17891
# Lasso                                                              20,413.65519
# LassoLars                                                          20,426.36006
# LassoCV                                                            20,430.82392
# Ridge                                                              20,760.16160
# RidgeCV                                                            20,760.16160
# TransformedTargetRegressor                                         21,151.93061
# LinearRegression                                                   21,151.93061
# Lars                                                               21,151.93061
# LarsCV                                                             21,151.93061
# LassoLarsIC                                                        21,151.93061
# LassoLarsCV                                                        21,151.93061
# ExtraTreeRegressor                                                  4,958.05212
# DecisionTreeRegressor                                               4,975.92111
# LinearSVR                                                           5,695.82616
# MLPRegressor                                                       15,980.87850
# RANSACRegressor                                                    45,314.05235
# KernelRidge                                                        21,365.09218
# GaussianProcessRegressor                                           29,956.03796
# PoissonRegressor              334,925,700,287,984,342,782,825,923,084,288.00000
#
#                                Time Taken  \
# Model
# OrthogonalMatchingPursuitCV       0.00893
# OrthogonalMatchingPursuit         0.00849
# RandomForestRegressor             1.79089
# KNeighborsRegressor               0.01274
# GradientBoostingRegressor         0.62270
# GammaRegressor                    0.01100
# HistGradientBoostingRegressor     0.18060
# LGBMRegressor                     0.06142
# ExtraTreesRegressor               0.51762
# SVR                               0.25491
# NuSVR                             0.14653
# QuantileRegressor                 0.19154
# DummyRegressor                    0.00507
# AdaBoostRegressor                 0.15064
# BaggingRegressor                  0.19048
# XGBRegressor                      0.24580
# ElasticNet                        0.00909
# ElasticNetCV                      0.05362
# TweedieRegressor                  0.01362
# PassiveAggressiveRegressor        0.01410
# SGDRegressor                      0.01471
# HuberRegressor                    0.01536
# BayesianRidge                     0.01053
# Lasso                             0.00986
# LassoLars                         0.00861
# LassoCV                           0.07678
# Ridge                             0.01062
# RidgeCV                           0.00749
# TransformedTargetRegressor        0.01413
# LinearRegression                  0.00657
# Lars                              0.00874
# LarsCV                            0.02447
# LassoLarsIC                       0.00981
# LassoLarsCV                       0.01303
# ExtraTreeRegressor                0.01559
# DecisionTreeRegressor             0.03351
# LinearSVR                         0.00776
# MLPRegressor                      0.80725
# RANSACRegressor                   0.07462
# KernelRidge                       0.37013
# GaussianProcessRegressor          0.74118
# PoissonRegressor                  0.00939
#
#                                                            mean_absolute_error
# Model
# OrthogonalMatchingPursuitCV                                        2,651.02085
# OrthogonalMatchingPursuit                                          2,695.19192
# RandomForestRegressor                                              2,696.51344
# KNeighborsRegressor                                                2,699.72588
# GradientBoostingRegressor                                          2,701.88038
# GammaRegressor                                                     2,706.20187
# HistGradientBoostingRegressor                                      2,709.33345
# LGBMRegressor                                                      2,715.69431
# ExtraTreesRegressor                                                2,729.30139
# SVR                                                                2,778.30082
# NuSVR                                                              2,778.43567
# QuantileRegressor                                                  2,784.07039
# DummyRegressor                                                     2,802.49959
# AdaBoostRegressor                                                  2,808.44104
# BaggingRegressor                                                   2,820.87184
# XGBRegressor                                                       2,903.63780
# ElasticNet                                                         2,938.53681
# ElasticNetCV                                                       2,948.22789
# TweedieRegressor                                                   2,948.41854
# PassiveAggressiveRegressor                                         2,965.69259
# SGDRegressor                                                       3,195.78940
# HuberRegressor                                                     3,235.43882
# BayesianRidge                                                      3,339.92143
# Lasso                                                              3,563.42078
# LassoLars                                                          3,564.01102
# LassoCV                                                            3,564.21766
# Ridge                                                              3,579.58714
# RidgeCV                                                            3,579.58714
# TransformedTargetRegressor                                         3,597.73865
# LinearRegression                                                   3,597.73865
# Lars                                                               3,597.73865
# LarsCV                                                             3,597.73865
# LassoLarsIC                                                        3,597.73865
# LassoLarsCV                                                        3,597.73865
# ExtraTreeRegressor                                                 3,783.08903
# DecisionTreeRegressor                                              3,801.78675
# LinearSVR                                                          4,532.57692
# MLPRegressor                                                       4,908.35478
# RANSACRegressor                                                    6,175.48951
# KernelRidge                                                        7,072.19667
# GaussianProcessRegressor                                          19,398.64841
# PoissonRegressor              15,239,647,045,017,873,342,229,844,590,592.00000

# %% [markdown]
# # **Data Fourth Strategy**
# ---

# %%
data_fourth = pd.read_csv('../data/fourth_strategy.csv')

# %%
data_fourth.columns
# Out:
# Index(['key', 'active_power_sum', 'reactive_power_sum', 'minutes_process_sum',
#        'gas_purgue', 'temperature_sum', 'wire_1', 'bulk_12', 'bulk_14',
#        'bulk_15'],
#       dtype='object')

# %%
X = data_fourth[[
    'active_power_sum', 'reactive_power_sum', 'minutes_process_sum',
    'gas_purgue', 'temperature_sum', 'wire_1', 'bulk_12', 'bulk_14',
    'bulk_15'
]]

y = data_fourth['temperature_sum']

# %%
regressor_model_fourth_strategy , predictions  = wra_regressor.fit(
    X_train,
    X_test,
    y_train,
    y_test
)
# Out:
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████| 42/42 [00:06<00:00,  6.56it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1785
# [LightGBM] [Info] Number of data points in the train set: 2731, number of used features: 7
# [LightGBM] [Info] Start training from score 6492.621384

# %%
regressor_model_fourth_strategy.sort_values('mean_absolute_error')
# Out:
#                                                               Adjusted R-Squared  \
# Model
# OrthogonalMatchingPursuitCV                                              0.03759
# OrthogonalMatchingPursuit                                                0.02822
# RandomForestRegressor                                                   -0.00781
# KNeighborsRegressor                                                     -0.01389
# GradientBoostingRegressor                                               -0.03353
# GammaRegressor                                                           0.03662
# HistGradientBoostingRegressor                                            0.00319
# LGBMRegressor                                                           -0.01546
# ExtraTreesRegressor                                                     -0.00808
# SVR                                                                     -0.01528
# NuSVR                                                                   -0.01510
# QuantileRegressor                                                       -0.01876
# DummyRegressor                                                          -0.02476
# AdaBoostRegressor                                                       -0.11383
# BaggingRegressor                                                        -0.08850
# XGBRegressor                                                            -0.18019
# ElasticNet                                                              -2.69156
# ElasticNetCV                                                            -2.58265
# TweedieRegressor                                                        -2.57563
# PassiveAggressiveRegressor                                              -3.86591
# SGDRegressor                                                           -11.70982
# HuberRegressor                                                         -14.09683
# BayesianRidge                                                          -19.25499
# Lasso                                                                  -33.94217
# LassoLars                                                              -33.98568
# LassoCV                                                                -34.00097
# Ridge                                                                  -35.13847
# RidgeCV                                                                -35.13847
# TransformedTargetRegressor                                             -36.51529
# LinearRegression                                                       -36.51529
# Lars                                                                   -36.51529
# LarsCV                                                                 -36.51529
# LassoLarsIC                                                            -36.51529
# LassoLarsCV                                                            -36.51529
# ExtraTreeRegressor                                                      -1.06125
# DecisionTreeRegressor                                                   -1.07613
# LinearSVR                                                               -1.72033
# MLPRegressor                                                           -20.41458
# RANSACRegressor                                                       -171.17659
# KernelRidge                                                            -37.27523
# GaussianProcessRegressor                                               -74.24490
# PoissonRegressor              -9,406,005,854,851,068,861,773,065,254,160,264,...
#
#                                                                        R-Squared  \
# Model
# OrthogonalMatchingPursuitCV                                              0.05157
# OrthogonalMatchingPursuit                                                0.04233
# RandomForestRegressor                                                    0.00683
# KNeighborsRegressor                                                      0.00084
# GradientBoostingRegressor                                               -0.01852
# GammaRegressor                                                           0.05062
# HistGradientBoostingRegressor                                            0.01767
# LGBMRegressor                                                           -0.00072
# ExtraTreesRegressor                                                      0.00656
# SVR                                                                     -0.00054
# NuSVR                                                                   -0.00036
# QuantileRegressor                                                       -0.00397
# DummyRegressor                                                          -0.00988
# AdaBoostRegressor                                                       -0.09765
# BaggingRegressor                                                        -0.07269
# XGBRegressor                                                            -0.16305
# ElasticNet                                                              -2.63795
# ElasticNetCV                                                            -2.53062
# TweedieRegressor                                                        -2.52370
# PassiveAggressiveRegressor                                              -3.79524
# SGDRegressor                                                           -11.52524
# HuberRegressor                                                         -13.87758
# BayesianRidge                                                          -18.96083
# Lasso                                                                  -33.43471
# LassoLars                                                              -33.47758
# LassoCV                                                                -33.49266
# Ridge                                                                  -34.61364
# RidgeCV                                                                -34.61364
# TransformedTargetRegressor                                             -35.97046
# LinearRegression                                                       -35.97046
# Lars                                                                   -35.97046
# LarsCV                                                                 -35.97046
# LassoLarsIC                                                            -35.97046
# LassoLarsCV                                                            -35.97046
# ExtraTreeRegressor                                                      -1.03131
# DecisionTreeRegressor                                                   -1.04598
# LinearSVR                                                               -1.68082
# MLPRegressor                                                           -20.10358
# RANSACRegressor                                                       -168.67610
# KernelRidge                                                            -36.71937
# GaussianProcessRegressor                                               -73.15213
# PoissonRegressor              -9,269,404,110,071,074,372,049,931,351,938,498,...
#
#                                                                            RMSE  \
# Model
# OrthogonalMatchingPursuitCV                                         3,387.86135
# OrthogonalMatchingPursuit                                           3,404.31949
# RandomForestRegressor                                               3,466.85156
# KNeighborsRegressor                                                 3,477.29110
# GradientBoostingRegressor                                           3,510.81320
# GammaRegressor                                                      3,389.56180
# HistGradientBoostingRegressor                                       3,447.87981
# LGBMRegressor                                                       3,479.99158
# ExtraTreesRegressor                                                 3,467.30850
# SVR                                                                 3,479.67963
# NuSVR                                                               3,479.37385
# QuantileRegressor                                                   3,485.63828
# DummyRegressor                                                      3,495.88260
# AdaBoostRegressor                                                   3,644.63893
# BaggingRegressor                                                    3,602.95870
# XGBRegressor                                                        3,751.64318
# ElasticNet                                                          6,635.15256
# ElasticNetCV                                                        6,536.54175
# TweedieRegressor                                                    6,530.13497
# PassiveAggressiveRegressor                                          7,617.77136
# SGDRegressor                                                       12,311.63102
# HuberRegressor                                                     13,418.02951
# BayesianRidge                                                      15,542.17891
# Lasso                                                              20,413.65519
# LassoLars                                                          20,426.36006
# LassoCV                                                            20,430.82392
# Ridge                                                              20,760.16160
# RidgeCV                                                            20,760.16160
# TransformedTargetRegressor                                         21,151.93061
# LinearRegression                                                   21,151.93061
# Lars                                                               21,151.93061
# LarsCV                                                             21,151.93061
# LassoLarsIC                                                        21,151.93061
# LassoLarsCV                                                        21,151.93061
# ExtraTreeRegressor                                                  4,958.05212
# DecisionTreeRegressor                                               4,975.92111
# LinearSVR                                                           5,695.82616
# MLPRegressor                                                       15,980.87850
# RANSACRegressor                                                    45,314.05235
# KernelRidge                                                        21,365.09218
# GaussianProcessRegressor                                           29,956.03796
# PoissonRegressor              334,925,700,287,984,342,782,825,923,084,288.00000
#
#                                Time Taken  \
# Model
# OrthogonalMatchingPursuitCV       0.01090
# OrthogonalMatchingPursuit         0.00909
# RandomForestRegressor             1.72319
# KNeighborsRegressor               0.01177
# GradientBoostingRegressor         0.60668
# GammaRegressor                    0.00756
# HistGradientBoostingRegressor     0.17838
# LGBMRegressor                     0.06154
# ExtraTreesRegressor               0.48225
# SVR                               0.21722
# NuSVR                             0.14371
# QuantileRegressor                 0.18323
# DummyRegressor                    0.00791
# AdaBoostRegressor                 0.17474
# BaggingRegressor                  0.18659
# XGBRegressor                      0.19093
# ElasticNet                        0.00844
# ElasticNetCV                      0.06289
# TweedieRegressor                  0.00902
# PassiveAggressiveRegressor        0.01435
# SGDRegressor                      0.01425
# HuberRegressor                    0.01735
# BayesianRidge                     0.00855
# Lasso                             0.00963
# LassoLars                         0.00648
# LassoCV                           0.07424
# Ridge                             0.00904
# RidgeCV                           0.00774
# TransformedTargetRegressor        0.00894
# LinearRegression                  0.00718
# Lars                              0.00873
# LarsCV                            0.01933
# LassoLarsIC                       0.00843
# LassoLarsCV                       0.01494
# ExtraTreeRegressor                0.01485
# DecisionTreeRegressor             0.03642
# LinearSVR                         0.00558
# MLPRegressor                      0.77098
# RANSACRegressor                   0.06167
# KernelRidge                       0.40296
# GaussianProcessRegressor          0.57585
# PoissonRegressor                  0.00936
#
#                                                            mean_absolute_error
# Model
# OrthogonalMatchingPursuitCV                                        2,651.02085
# OrthogonalMatchingPursuit                                          2,695.19192
# RandomForestRegressor                                              2,696.51344
# KNeighborsRegressor                                                2,699.72588
# GradientBoostingRegressor                                          2,701.88038
# GammaRegressor                                                     2,706.20187
# HistGradientBoostingRegressor                                      2,709.33345
# LGBMRegressor                                                      2,715.69431
# ExtraTreesRegressor                                                2,729.30139
# SVR                                                                2,778.30082
# NuSVR                                                              2,778.43567
# QuantileRegressor                                                  2,784.07039
# DummyRegressor                                                     2,802.49959
# AdaBoostRegressor                                                  2,808.44104
# BaggingRegressor                                                   2,820.87184
# XGBRegressor                                                       2,903.63780
# ElasticNet                                                         2,938.53681
# ElasticNetCV                                                       2,948.22789
# TweedieRegressor                                                   2,948.41854
# PassiveAggressiveRegressor                                         2,965.69259
# SGDRegressor                                                       3,195.78940
# HuberRegressor                                                     3,235.43882
# BayesianRidge                                                      3,339.92143
# Lasso                                                              3,563.42078
# LassoLars                                                          3,564.01102
# LassoCV                                                            3,564.21766
# Ridge                                                              3,579.58714
# RidgeCV                                                            3,579.58714
# TransformedTargetRegressor                                         3,597.73865
# LinearRegression                                                   3,597.73865
# Lars                                                               3,597.73865
# LarsCV                                                             3,597.73865
# LassoLarsIC                                                        3,597.73865
# LassoLarsCV                                                        3,597.73865
# ExtraTreeRegressor                                                 3,783.08903
# DecisionTreeRegressor                                              3,801.78675
# LinearSVR                                                          4,532.57692
# MLPRegressor                                                       4,908.35478
# RANSACRegressor                                                    6,175.48951
# KernelRidge                                                        7,072.19667
# GaussianProcessRegressor                                          19,398.64841
# PoissonRegressor              15,239,647,045,017,873,342,229,844,590,592.00000

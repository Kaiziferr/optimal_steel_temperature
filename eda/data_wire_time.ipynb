# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import functions as fa

# %% [markdown]
# # **Config**

# %%
sns.set_theme(style="darkgrid")
title_data = 'Wire'
paleta = sns.color_palette("tab10").as_hex()

# %% [markdown]
# # **Data**
# ---
# Contains information time about Wire
#
# - **key** is used to identify the steel batch number.
# - **Wire** wire materials data (time)

# %%
url_data_wire= "https://drive.google.com/file/d/12LIRw-e7gahPDS63eNRW9ljLBYBXwTnK/view?usp=sharing"
url_data_wire = 'https://drive.google.com/uc?id=' + url_data_wire.split('/')[-2]
data_wire = pd.read_csv(url_data_wire)

# %%
data_wire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   object
#  2   Wire 2  1079 non-null   object
#  3   Wire 3  63 non-null     object
#  4   Wire 4  14 non-null     object
#  5   Wire 5  1 non-null      object
#  6   Wire 6  73 non-null     object
#  7   Wire 7  11 non-null     object
#  8   Wire 8  19 non-null     object
#  9   Wire 9  29 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 240.8+ KB

# %%
data_wire.head()
# Out:
#    key               Wire 1               Wire 2 Wire 3 Wire 4 Wire 5 Wire 6  \
# 0    1  2019-05-03 11:11:41                  NaN    NaN    NaN    NaN    NaN
# 1    2  2019-05-03 11:46:10                  NaN    NaN    NaN    NaN    NaN
# 2    3  2019-05-03 12:13:47                  NaN    NaN    NaN    NaN    NaN
# 3    4  2019-05-03 12:48:05                  NaN    NaN    NaN    NaN    NaN
# 4    5  2019-05-03 13:18:15  2019-05-03 13:32:06    NaN    NaN    NaN    NaN
#
#   Wire 7 Wire 8 Wire 9
# 0    NaN    NaN    NaN
# 1    NaN    NaN    NaN
# 2    NaN    NaN    NaN
# 3    NaN    NaN    NaN
# 4    NaN    NaN    NaN

# %%
data_wire.shape
# Out:
# (3081, 10)

# %%
data_wire['key'].duplicated().sum()
# Out:
# 0

# %%
fa.porcentaje_nulos_x_caracteristica(data_wire)

# %% [markdown]
# The wire with less null values is the wire type 1

# %%
data_wire.isnull().sum()/data_wire.shape[0]
# Out:
# key       0.000000
# Wire 1    0.008439
# Wire 2    0.649789
# Wire 3    0.979552
# Wire 4    0.995456
# Wire 5    0.999675
# Wire 6    0.976306
# Wire 7    0.996430
# Wire 8    0.993833
# Wire 9    0.990587
# dtype: float64

# %%
fa.null_features_per_record(data_wire)

# %% [markdown]
# - Hay varios valores nulos en las mismas filas.
# - -There are multiple null values in the same rows-

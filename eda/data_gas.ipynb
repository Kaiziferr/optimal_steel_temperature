# %%
import sys

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append('../source/')

import eda

# %% [markdown]
# # **Config**
# ---

# %%
sns.set(style="darkgrid")
pd.set_option('display.float_format', '{:,.2f}'.format)
title_data = 'Data Bulk'
paleta = sns.color_palette('Set2').as_hex()
random_seed=73
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# # **Data**
# ---
# Contains information about gas consumption.
#
# - **key** is used to identify the steel batch number.
# - **Gas 1** data for gas purge. Gas purging is often done in a ladle to accelerate the refining operations in steel industries.

# %%
url_data_gas= "hhttps://drive.google.com/file/d/12WGZjrggZ8Q-rTtX41tZPHYjH0ztZbwm/view?usp=sharing"
url_data_gas = 'https://drive.google.com/uc?id=' + url_data_gas.split('/')[-2]
data_gas = pd.read_csv(url_data_gas)

# %%
data_gas.shape
# Out:
# (3239, 2)

# %%
data_gas['key'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - There are not duplicated

# %%
data_gas.head()
# Out:
#    key  Gas 1
# 0    1  29.75
# 1    2  12.56
# 2    3  28.55
# 3    4  18.84
# 4    5   5.41

# %%
data_gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3239 non-null   int64
#  1   Gas 1   3239 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 50.7 KB

# %%
eda.porcentaje_nulos_x_caracteristica(data_gas)

# %% [markdown]
# - There are not null values

# %%
fig, ax = plt.subplots(1, 2, figsize=(40, 5))
sns.violinplot(data=data_gas, x="Gas 1", fill=False, ax=ax[0])
ax[0].set_title('ViolinPlot Gas')
sns.histplot(data=data_gas, x="Gas 1", fill=False, ax=ax[1])
ax[1].set_title('Hist Gas')
plt.show()

# %% [markdown]
# - The gas consumed for the batch steel process is concentrated between 0 and 20 (unit of measurement is unknown)
